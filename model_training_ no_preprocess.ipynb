# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from pathlib import Path

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight

import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.preprocessing import image
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, BatchNormalization, GlobalAveragePooling2D
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau

# %%
DATASET_PATH = "dataset"
print("Dataset var mı?", os.path.exists(DATASET_PATH))
print("TensorFlow version:", tf.__version__)

gpus = tf.config.list_physical_devices("GPU")
if gpus:
    print("GPU bulundu:")
    for gpu in gpus:
        print(gpu)
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print("GPU memory growth aktif edildi.")
    except RuntimeError as e:
        print(e)
else:
    print("GPU bulunamadı. Model CPU ile çalışacak.")
# Out:
# Dataset var mı? True
# TensorFlow version: 2.20.0
# GPU bulundu:
# PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')
# GPU memory growth aktif edildi.

# %%
for folder in os.listdir(DATASET_PATH):
    folder_path = os.path.join(DATASET_PATH, folder)
    if os.path.isdir(folder_path):
        print("Bulunan Sınıf:", folder)

image_extensions = [".jpg", ".jpeg", ".png", ".webp"]
data = []

for img_path in Path(DATASET_PATH).rglob("*"):
    if img_path.suffix.lower() in image_extensions:
        label = img_path.parent.name
        data.append({
            "filepath": str(img_path),
            "label": label
        })

df = pd.DataFrame(data)

print("\n--- Veri Seti Özeti ---")
print(df["label"].value_counts())
print("Toplam görsel sayısı:", len(df))
print("Toplam class sayısı:", df["label"].nunique())

plt.figure(figsize=(10,5))
sns.countplot(data=df, x="label", order=df["label"].value_counts().index)
plt.xticks(rotation=45)
plt.title("Class Dağılımı")
plt.xlabel("Class")
plt.ylabel("Görsel Sayısı")
plt.show()
# Out:
# Bulunan Sınıf: StyleGAN
# Bulunan Sınıf: DALL-E
# Bulunan Sınıf: Midjourney
# Bulunan Sınıf: Real
# Bulunan Sınıf: FaceShifter
# Bulunan Sınıf: Stable Diffusion
# Bulunan Sınıf: Face2Face
# Bulunan Sınıf: FaceSwap
# Bulunan Sınıf: NeuralTextures
# Bulunan Sınıf: DeepFaceLab
#
# --- Veri Seti Özeti ---
# label
# Real                5890
# Stable Diffusion    2098
# DALL-E              2000
# DeepFaceLab         1606
# FaceSwap            1600
# StyleGAN            1000
# Face2Face           1000
# FaceShifter         1000
# NeuralTextures      1000
# Midjourney           930
# Name: count, dtype: int64
# Toplam görsel sayısı: 18124
# Toplam class sayısı: 10

# %%
train_df, temp_df = train_test_split(df, test_size=0.30, stratify=df["label"], random_state=42)
val_df, test_df = train_test_split(temp_df, test_size=0.50, stratify=temp_df["label"], random_state=42)

print("Train:", len(train_df))
print("Validation:", len(val_df))
print("Test:", len(test_df))

IMG_SIZE = 128
BATCH_SIZE = 64

train_datagen = ImageDataGenerator(rescale=1./255)
val_test_datagen = ImageDataGenerator(rescale=1./255)

train_gen = train_datagen.flow_from_dataframe(dataframe=train_df, x_col="filepath", y_col="label", target_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH_SIZE, class_mode="categorical")
val_gen = val_test_datagen.flow_from_dataframe(dataframe=val_df, x_col="filepath", y_col="label", target_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH_SIZE, class_mode="categorical", shuffle=False)
test_gen = val_test_datagen.flow_from_dataframe(dataframe=test_df, x_col="filepath", y_col="label", target_size=(IMG_SIZE, IMG_SIZE), batch_size=BATCH_SIZE, class_mode="categorical", shuffle=False)

print(train_gen.class_indices)
num_classes = len(train_gen.class_indices)
print("Class sayısı:", num_classes)
# Out:
# Train: 12686
# Validation: 2719
# Test: 2719
# Found 12686 validated image filenames belonging to 10 classes.
# Found 2719 validated image filenames belonging to 10 classes.
# Found 2719 validated image filenames belonging to 10 classes.
# {'DALL-E': 0, 'DeepFaceLab': 1, 'Face2Face': 2, 'FaceShifter': 3, 'FaceSwap': 4, 'Midjourney': 5, 'NeuralTextures': 6, 'Real': 7, 'Stable Diffusion': 8, 'StyleGAN': 9}
# Class sayısı: 10

# %%
model = Sequential([
    Conv2D(32, (3,3), activation="relu", padding="same", input_shape=(IMG_SIZE, IMG_SIZE, 3)),
    BatchNormalization(),
    Conv2D(32, (3,3), activation="relu", padding="same"),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(64, (3,3), activation="relu", padding="same"),
    BatchNormalization(),
    Conv2D(64, (3,3), activation="relu", padding="same"),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(128, (3,3), activation="relu", padding="same"),
    BatchNormalization(),
    Conv2D(128, (3,3), activation="relu", padding="same"),
    BatchNormalization(),
    MaxPooling2D(2,2),

    Conv2D(256, (3,3), activation="relu", padding="same"),
    BatchNormalization(),
    Conv2D(256, (3,3), activation="relu", padding="same"),
    BatchNormalization(),
    MaxPooling2D(2,2),

    GlobalAveragePooling2D(),

    Dense(128, activation="relu"),
    BatchNormalization(),
    Dropout(0.5),

    Dense(num_classes, activation="softmax")
])

model.compile(optimizer="adam", loss="categorical_crossentropy", metrics=["accuracy"])

callbacks = [
    EarlyStopping(monitor="val_loss", patience=8, restore_best_weights=True),
    ModelCheckpoint("deepfake_multiclass_cnn_no_preprocess.keras", monitor="val_loss", save_best_only=True),
    ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=3, min_lr=1e-6, verbose=1)
]
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(train_df['label']),
    y=train_df['label']
)

train_class_indices = train_gen.class_indices
weight_dict = {train_class_indices[cls]: weight for cls, weight in zip(np.unique(train_df['label']), class_weights)}

history = model.fit(train_gen, validation_data=val_gen, epochs=40, callbacks=callbacks, class_weight=weight_dict)
# Out:
# Epoch 1/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 66s 223ms/step - accuracy: 0.3931 - loss: 1.7543 - val_accuracy: 0.3170 - val_loss: 3.1607 - learning_rate: 0.0010
# Epoch 2/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 28s 138ms/step - accuracy: 0.5509 - loss: 1.2547 - val_accuracy: 0.2608 - val_loss: 2.3853 - learning_rate: 0.0010
# Epoch 3/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 28s 139ms/step - accuracy: 0.6491 - loss: 0.9990 - val_accuracy: 0.4711 - val_loss: 1.4198 - learning_rate: 0.0010
# Epoch 4/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 28s 138ms/step - accuracy: 0.7066 - loss: 0.8508 - val_accuracy: 0.4469 - val_loss: 2.1458 - learning_rate: 0.0010
# Epoch 5/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 31s 154ms/step - accuracy: 0.7505 - loss: 0.7297 - val_accuracy: 0.4053 - val_loss: 2.7604 - learning_rate: 0.0010
# Epoch 6/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - accuracy: 0.8006 - loss: 0.6035 - val_accuracy: 0.6337 - val_loss: 1.2398 - learning_rate: 0.0010
# Epoch 7/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - accuracy: 0.8402 - loss: 0.4843 - val_accuracy: 0.7624 - val_loss: 0.6934 - learning_rate: 0.0010
# Epoch 8/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - accuracy: 0.8716 - loss: 0.3917 - val_accuracy: 0.7749 - val_loss: 0.6357 - learning_rate: 0.0010
# Epoch 9/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 28s 139ms/step - accuracy: 0.9112 - loss: 0.2683 - val_accuracy: 0.6922 - val_loss: 1.0017 - learning_rate: 0.0010
# Epoch 10/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 27s 135ms/step - accuracy: 0.9348 - loss: 0.1997 - val_accuracy: 0.8279 - val_loss: 0.5570 - learning_rate: 0.0010
# Epoch 11/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 27s 138ms/step - accuracy: 0.9430 - loss: 0.1616 - val_accuracy: 0.7124 - val_loss: 0.8541 - learning_rate: 0.0010
# Epoch 12/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 29s 144ms/step - accuracy: 0.9453 - loss: 0.1581 - val_accuracy: 0.5509 - val_loss: 2.3627 - learning_rate: 0.0010
# Epoch 13/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 29s 143ms/step - accuracy: 0.9552 - loss: 0.1307 - val_accuracy: 0.8727 - val_loss: 0.4111 - learning_rate: 0.0010
# Epoch 14/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 29s 145ms/step - accuracy: 0.9552 - loss: 0.1199 - val_accuracy: 0.8989 - val_loss: 0.3596 - learning_rate: 0.0010
# Epoch 15/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 28s 138ms/step - accuracy: 0.9582 - loss: 0.1226 - val_accuracy: 0.8566 - val_loss: 0.4662 - learning_rate: 0.0010
# Epoch 16/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 28s 139ms/step - accuracy: 0.9752 - loss: 0.0627 - val_accuracy: 0.5903 - val_loss: 1.3377 - learning_rate: 0.0010
# Epoch 17/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - accuracy: 0.9760 - loss: 0.0708 - val_accuracy: 0.9058 - val_loss: 0.3353 - learning_rate: 0.0010
# Epoch 18/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 28s 141ms/step - accuracy: 0.9793 - loss: 0.0516 - val_accuracy: 0.9172 - val_loss: 0.2412 - learning_rate: 0.0010
# Epoch 19/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 27s 134ms/step - accuracy: 0.9824 - loss: 0.0443 - val_accuracy: 0.8363 - val_loss: 0.5398 - learning_rate: 0.0010
# Epoch 20/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 27s 133ms/step - accuracy: 0.9742 - loss: 0.0732 - val_accuracy: 0.7915 - val_loss: 0.9003 - learning_rate: 0.0010
# Epoch 21/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9638 - loss: 0.1048
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 27s 138ms/step - accuracy: 0.9624 - loss: 0.1029 - val_accuracy: 0.8492 - val_loss: 0.5526 - learning_rate: 0.0010
# Epoch 22/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 27s 137ms/step - accuracy: 0.9888 - loss: 0.0297 - val_accuracy: 0.9577 - val_loss: 0.1295 - learning_rate: 5.0000e-04
# Epoch 23/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 27s 137ms/step - accuracy: 0.9946 - loss: 0.0176 - val_accuracy: 0.9684 - val_loss: 0.0923 - learning_rate: 5.0000e-04
# Epoch 24/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 27s 135ms/step - accuracy: 0.9959 - loss: 0.0110 - val_accuracy: 0.9662 - val_loss: 0.1092 - learning_rate: 5.0000e-04
# Epoch 25/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 26s 131ms/step - accuracy: 0.9972 - loss: 0.0088 - val_accuracy: 0.9713 - val_loss: 0.1177 - learning_rate: 5.0000e-04
# Epoch 26/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9959 - loss: 0.0091
# Epoch 26: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - accuracy: 0.9963 - loss: 0.0098 - val_accuracy: 0.9717 - val_loss: 0.1199 - learning_rate: 5.0000e-04
# Epoch 27/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 27s 137ms/step - accuracy: 0.9984 - loss: 0.0060 - val_accuracy: 0.9783 - val_loss: 0.0754 - learning_rate: 2.5000e-04
# Epoch 28/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 27s 137ms/step - accuracy: 0.9990 - loss: 0.0044 - val_accuracy: 0.9816 - val_loss: 0.0741 - learning_rate: 2.5000e-04
# Epoch 29/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 28s 143ms/step - accuracy: 0.9987 - loss: 0.0044 - val_accuracy: 0.9809 - val_loss: 0.0714 - learning_rate: 2.5000e-04
# Epoch 30/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 28s 140ms/step - accuracy: 0.9986 - loss: 0.0035 - val_accuracy: 0.9511 - val_loss: 0.1896 - learning_rate: 2.5000e-04
# Epoch 31/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 27s 135ms/step - accuracy: 0.9982 - loss: 0.0045 - val_accuracy: 0.9831 - val_loss: 0.0782 - learning_rate: 2.5000e-04
# Epoch 32/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.9994 - loss: 0.0027
# Epoch 32: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 26s 131ms/step - accuracy: 0.9996 - loss: 0.0025 - val_accuracy: 0.9838 - val_loss: 0.0755 - learning_rate: 2.5000e-04
# Epoch 33/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 27s 135ms/step - accuracy: 0.9997 - loss: 0.0018 - val_accuracy: 0.9820 - val_loss: 0.0723 - learning_rate: 1.2500e-04
# Epoch 34/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 27s 135ms/step - accuracy: 0.9995 - loss: 0.0023 - val_accuracy: 0.9853 - val_loss: 0.0749 - learning_rate: 1.2500e-04
# Epoch 35/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.9995 - loss: 0.0021
# Epoch 35: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 27s 137ms/step - accuracy: 0.9995 - loss: 0.0022 - val_accuracy: 0.9842 - val_loss: 0.0757 - learning_rate: 1.2500e-04
# Epoch 36/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 27s 136ms/step - accuracy: 0.9998 - loss: 0.0015 - val_accuracy: 0.9846 - val_loss: 0.0726 - learning_rate: 6.2500e-05
# Epoch 37/40
# 199/199 ━━━━━━━━━━━━━━━━━━━━ 27s 134ms/step - accuracy: 0.9998 - loss: 0.0015 - val_accuracy: 0.9838 - val_loss: 0.0716 - learning_rate: 6.2500e-05

# %%
test_loss, test_acc = model.evaluate(test_gen)
print("Test Accuracy:", test_acc)
print("Test Loss:", test_loss)
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 4s 99ms/step - accuracy: 0.9801 - loss: 0.0875
# Test Accuracy: 0.9801397323608398
# Test Loss: 0.08747587352991104

# %%
# Accuracy Grafiği
plt.figure(figsize=(8,5))
plt.plot(history.history["accuracy"], label="Train Accuracy")
plt.plot(history.history["val_accuracy"], label="Validation Accuracy")
plt.title("Model Accuracy")
plt.xlabel("Epoch")
plt.ylabel("Accuracy")
plt.legend()
plt.show()

# Loss Grafiği
plt.figure(figsize=(8,5))
plt.plot(history.history["loss"], label="Train Loss")
plt.plot(history.history["val_loss"], label="Validation Loss")
plt.title("Model Loss")
plt.xlabel("Epoch")
plt.ylabel("Loss")
plt.legend()
plt.show()

# Confusion Matrix ve Raporlama
pred_probs = model.predict(test_gen)
pred_classes = np.argmax(pred_probs, axis=1)
true_classes = test_gen.classes
class_names = list(test_gen.class_indices.keys())

cm = confusion_matrix(true_classes, pred_classes)
plt.figure(figsize=(12,10))
sns.heatmap(cm, annot=True, fmt="d", xticklabels=class_names, yticklabels=class_names)
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Confusion Matrix")
plt.xticks(rotation=45)
plt.show()

print(classification_report(true_classes, pred_classes, target_names=class_names))
# Out:
# 43/43 ━━━━━━━━━━━━━━━━━━━━ 6s 117ms/step
#                   precision    recall  f1-score   support
#
#           DALL-E       0.95      0.96      0.96       300
#      DeepFaceLab       0.97      0.97      0.97       241
#        Face2Face       0.99      1.00      0.99       150
#      FaceShifter       0.99      0.99      0.99       150
#         FaceSwap       1.00      0.99      1.00       240
#       Midjourney       0.94      0.94      0.94       140
#   NeuralTextures       0.98      0.98      0.98       150
#             Real       0.99      0.99      0.99       883
# Stable Diffusion       0.98      0.96      0.97       315
#         StyleGAN       0.97      1.00      0.99       150
#
#         accuracy                           0.98      2719
#        macro avg       0.98      0.98      0.98      2719
#     weighted avg       0.98      0.98      0.98      2719

# %%
def predict_single_image_with_plot(img_path):
    img = image.load_img(img_path, target_size=(IMG_SIZE, IMG_SIZE))
    img_array = image.img_to_array(img)
    img_array = img_array / 255.0
    img_array = np.expand_dims(img_array, axis=0)

    predictions = model.predict(img_array)[0]
    index_to_class = {v: k for k, v in train_gen.class_indices.items()}
    class_names = [index_to_class[i] for i in range(len(predictions))]
    predicted_index = np.argmax(predictions)
    predicted_class = class_names[predicted_index]

    plt.figure(figsize=(10,5))
    sns.barplot(x=class_names, y=predictions)
    plt.title("Class Olasılıkları")
    plt.xlabel("Class")
    plt.ylabel("Probability")
    plt.show()

    print("Tahmin:", predicted_class)
    if predicted_class.lower() == "real":
        print("Sonuç: Gerçek görsel")
    else:
        print("Sonuç: Sahte görsel")
        print("AI Kaynağı:", predicted_class)

# %%
sample_img = test_df.iloc[281]["filepath"]
print("Gerçek label:", test_df.iloc[281]["label"])
predict_single_image_with_plot(sample_img)
